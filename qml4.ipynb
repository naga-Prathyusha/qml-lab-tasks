# %% [markdown]
# <a href="https://colab.research.google.com/github/naga-Prathyusha/qml-lab-tasks/blob/main/qml4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Aim: To verify Pauli matrix commutation relations and decompose a gate using Euler angles.
1.Verify the fundamental commutation and anti-commutation relations of Pauli matrices (X, Y,Z)
2.Implement and validate Z-Y-Z Euler angle decomposition for arbitrary single-qubit gates
3.Demonstrate the decomposition on standard quantum gates (X, Y, Z, H, S, T) and Cirq operations.

2. Algorithm
2.1 Pauli Matrix Verification
a. Symbolically define Pauli matrices using SymPy
b. Compute commutators [A,B] = AB-BA and verify [σi,σj] = 2iεijkσk
c. Compute anti-commutators {A,B} = AB+BA and verify {σi,σj} = 2δijI
2.2 Z-Y-Z Decomposition
a. Check matrix unitarity: UTU = I
b. Extract global phase from determinant
c. Solve for Euler angles (α, β, γ) in:
d. U = e^iφ Rz(α)Ry(β)Rz(γ)
e. Handle special cases when β ≈ 0 or π
f. Reconstruct matrix to validate decomposition
2.3 Testing
a. Standard gates: X, Y, Z, Hadamard (H), Phase (S), π/8 (T)
b. Random unitary matrices
c. Optional Cirq integration for hardware verification

# %%
import numpy as np
import cmath
import sympy as sp

print("\n" + "="*50)
print("TASK 4: COMMUTATION RELATIONS AND EULER ANGLES")
print("="*50)

# Pauli Matrices
I = sp.eye(2)
sx = sp.Matrix([[0, 1], [1, 0]])
sy = sp.Matrix([[0, -sp.I], [sp.I, 0]])
sz = sp.Matrix([[1, 0], [0, -1]])
paulis = {'X': sx, 'Y': sy, 'Z': sz}

# Commutator and Anti-commutator
def comm(A, B):
    return sp.simplify(A * B - B * A)

def anti(A, B):
    return sp.simplify(A * B + B * A)

print("\n=== Commutation relations ===")
for (a, b, k) in [('X', 'Y', 'Z'), ('Y', 'Z', 'X'), ('Z', 'X', 'Y')]:
    lhs = comm(paulis[a], paulis[b])
    rhs = 2 * sp.I * paulis[k]
    print(f"[{a},{b}] =\n{lhs}\nExpected:\n{rhs}\n")

print("\n=== Anti-commutation relations ===")
for i in ['X', 'Y', 'Z']:
    for j in ['X', 'Y', 'Z']:
        lhs = anti(paulis[i], paulis[j])
        rhs = 2 * (1 if i == j else 0) * I
        print(f"{{{i},{j}}} =\n{lhs}\nExpected:\n{rhs}\n")

# --- Unitary checks and Euler decomposition ---
def is_unitary(U, tol=1e-8):
    return np.allclose(U.conj().T @ U, np.eye(2), atol=tol)

def decompose_zyz(U, tol=1e-8):
    U = np.array(U, dtype=complex)
    if not is_unitary(U):
        raise ValueError("Matrix is not unitary.")
    detU = np.linalg.det(U)
    phi = cmath.phase(detU) / 2
    U0 = U * np.exp(-1j * phi)
    detU0 = np.linalg.det(U0)
    U0 = U0 / np.sqrt(detU0)

    a = U0[0, 0]
    b = U0[0, 1]

    beta = 2 * np.arccos(min(1.0, max(0.0, abs(a))))
    if np.isclose(np.sin(beta / 2), 0, atol=tol):
        alpha = 2 * (-cmath.phase(a))
        gamma = 0.0
    else:
        phi1 = -cmath.phase(a)
        phi2 = -cmath.phase(-b)
        alpha = phi1 + phi2
        gamma = phi1 - phi2
    return float(phi), float(alpha), float(beta), float(gamma)

# Rotation matrices
def Rz(theta):
    return np.array([[np.exp(-1j * theta / 2), 0],
                     [0, np.exp(1j * theta / 2)]], dtype=complex)

def Ry(theta):
    return np.array([[np.cos(theta / 2), -np.sin(theta / 2)],
                     [np.sin(theta / 2),  np.cos(theta / 2)]], dtype=complex)

def reconstruct(phi, alpha, beta, gamma):
    return np.exp(1j * phi) * (Rz(alpha) @ Ry(beta) @ Rz(gamma))

def Rx(theta):
    return np.cos(theta / 2) * np.eye(2) - 1j * np.sin(theta / 2) * np.array(sx, dtype=complex)

# Example gates
examples = {
    "Rx(pi/3)": Rx(np.pi / 3),
    "Ry(pi/4)": Ry(np.pi / 4),
    "Rz(pi/2)": Rz(np.pi / 2),
    "H": (1 / np.sqrt(2)) * np.array([[1, 1], [1, -1]], dtype=complex),
    "S": np.array([[1, 0], [0, 1j]], dtype=complex),
    "T": np.array([[1, 0], [0, np.exp(1j * np.pi / 4)]], dtype=complex),
}

print("\n=== Z–Y–Z Euler Decomposition ===")
for name, U in examples.items():
    phi, alpha, beta, gamma = decompose_zyz(U)
    print(f"{name}:\n φ={phi:.6f}, α={alpha:.6f}, β={beta:.6f}, γ={gamma:.6f}\n")

# Optional: Cirq test
try:
    import cirq
    print("\nCirq example decomposition for H gate:")
    q = cirq.LineQubit(0)
    H_op = cirq.H(q)
    U = cirq.unitary(H_op)
    phi, alpha, beta, gamma = decompose_zyz(U)
    print(f"Cirq H: φ={phi:.6f}, α={alpha:.6f}, β={beta:.6f}, γ={gamma:.6f}")
except ImportError:
    print("\nCirq not installed. Skipping Cirq examples.")
# Out:
# ==================================================
# TASK 4: COMMUTATION RELATIONS AND EULER ANGLES
# ==================================================
#
# === Commutation relations ===
# [X,Y] =
# Matrix([[2*I, 0], [0, -2*I]])
# Expected:
# Matrix([[2*I, 0], [0, -2*I]])
#
# [Y,Z] =
# Matrix([[0, 2*I], [2*I, 0]])
# Expected:
# Matrix([[0, 2*I], [2*I, 0]])
#
# [Z,X] =
# Matrix([[0, 2], [-2, 0]])
# Expected:
# Matrix([[0, 2], [-2, 0]])
#
#
# === Anti-commutation relations ===
# {X,X} =
# Matrix([[2, 0], [0, 2]])
# Expected:
# Matrix([[2, 0], [0, 2]])
#
# {X,Y} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {X,Z} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {Y,X} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {Y,Y} =
# Matrix([[2, 0], [0, 2]])
# Expected:
# Matrix([[2, 0], [0, 2]])
#
# {Y,Z} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {Z,X} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {Z,Y} =
# Matrix([[0, 0], [0, 0]])
# Expected:
# Matrix([[0, 0], [0, 0]])
#
# {Z,Z} =
# Matrix([[2, 0], [0, 2]])
# Expected:
# Matrix([[2, 0], [0, 2]])
#
#
# === Z–Y–Z Euler Decomposition ===
# Rx(pi/3):
#  φ=0.000000, α=-1.570796, β=1.047198, γ=1.570796
#
# Ry(pi/4):
#  φ=0.000000, α=0.000000, β=0.785398, γ=-0.000000
#
# Rz(pi/2):
#  φ=0.000000, α=1.570796, β=0.000000, γ=0.000000
#
# H:
#  φ=1.570796, α=0.000000, β=1.570796, γ=3.141593
#
# S:
#  φ=0.785398, α=1.570796, β=0.000000, γ=0.000000
#
# T:
#  φ=0.392699, α=0.785398, β=0.000000, γ=0.000000
#
#
# Cirq not installed. Skipping Cirq examples.

# %%
Result
Commutation properties and Euler angle decomposition were successfully demonstrated.
